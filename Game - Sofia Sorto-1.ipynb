# %% [markdown]
# Hello!
#
# ✨Prepare yourself for an extraordinary adventure into the beloved world of Pixar!✨
# (Disney/Pixar."Pixar", https://www.pixar.com/feature-films-launch).
# Immerse yourself in this amazing journey in which each step leads you either to
# victory or game over. You will encounter challenges, meet new characters
# and demonstrate your knowledge of Pixar movies!
# Will you conquer the game and emerge victorious, or will the challenges prove
# too difficult?
# Get ready for an animated quest filled with fun, nostalgia, and the spirit of
# Pixar magic!✨🎉
#
# Bugs: - Not having only two attempts in music input if sports is written as the
#         second option.
#        - Not having only two attempts in advice input if Randall is written as the
#         second option.

# %%
# importing system and random modules which will be used along the game

import sys
import random


# defining the fail function of the game

def fail():  
    print("\nSorry, you're out of attempts. Game over! 🚫\n ")
    input (prompt = "\n Press 'Enter' to exit.")
    sys.exit()


# defining the introduction to the game (hinting where the adventure will start.)

def welcome():
    
    print(f""" \nHello! Welcome to the great Pixar Adventure✨.\n""")
    
    # list of options for the movie input.

    movie_lst = ['Coco','Toy Story', 'Cars', "Monster's Inc", 'Ratatouille', 'Finding Nemo'] 
    

    print(movie_lst)


    movie = input ( prompt = " \nFrom the given list, which movie was released first? " ).title()
    
    #establishing the attempts for the first whiile loop

    attempts = 2 
    
    while attempts > 0:
        
        if movie == "Toy Story" or "Toy" in movie or "Story" in movie:
            print("""\nCorrect! Do you know how to fly? If not, we will fall with style onto 
our first stage.🚀 \n""")
        
            stage1()
            break # if the input of the player is Toy Story the loop will break
            
    
        else:
            attempts -= 1
            if attempts > 0 :
                movie = input ( prompt = " \nTry again! Which movie was released first? " ).title()
        
            else:
                # if the player does not answer correctly in two attempts: Game Over 
                fail()

# defining the first stage

def stage1():
    stage1 = input(prompt = "Press 'Enter' to continue: ")

    # defining attempts for the while loop
    
    attempts = 2

    print("🐎" * 40)
    
    helper = input ( prompt = """ \nYou are now in Andy's room and you have to prepare yourself 
for a long trip into another world, but you need help preparing for it. 
Choose the best character to help you with this task. 
                
Rex
Mrs. Potato Head
Jessie
Buzz \n""" ).title()

    while attempts > 0:
        
        # in the input helper the correct answer should at least have "Potato"
        
        if helper == "Mrs. Potato Head" or "Potato" in helper:
            print( " \nOf course! She knows how to be prepared! ✅ \n" )
            print ( f""" \nYou started in Andy’s room to prepare to your adventure with 
the help of {helper}. Let's see where the journey continues.""")
            stage2()
            break # break the loop if correct answer
    
        elif helper == "Rex":
            helper = input(prompt = """ \nAre you sure? He is really kind but a little bit 
clumsy😬. Try again! \n""").title()
            attempts -= 1
        
        else:
            attempts -= 1
            if attempts > 0:
                helper = input(prompt = " \nTry again! Character known for preparing someone in particular! \n").title()
        
            else:
                # if the player does not answer correctly in two attempts: Game Over
                fail()        
     
    
# definining stage 2
            
def stage2(): 

    print( '🎶💀🌸' * 14)
    
    # establishing number of attempts for while loop
    
    attempts = 2
    
    try:
        miguel = input ( prompt = """\nSeñoras y señores buenas tardes, buenas noches - 
Welcome to Santa Cecilia! Remember me? I used to go by 'De la Crucito,' 
But, what's my name? If you don't know press 'Enter' to continue. \n""" ).title()


        if miguel == "Miguel":
               print( '\n*insert mexican scream* Awesome! \n')
        else:
               print( " \nNice to meet you, my name is Miguel! \n")
    except ValueError as e:
        print('An error has ocurred.')
        
    
    name = input ( prompt = "Don't forget to be polite! Hello, Miguel! My name is ").title()
    
    if bool(name) == True:
        pass
        
    if bool(name) == False:
        # if the user does not input their name they fail (necessary for the partner challenge/input)
        fail()
        
    print( '🎶💀🌸' * 14)

    
    music = input ( prompt = """\nCould you imagine world without ___? 
Poor Miguel having to deal with that! Fill in the blank with an option from the following list:

Food
Music
Sports
Jokes
Sleep
Dessert\n""" ).casefold()
    
    #defining attempts for the while loop.
    
    attempts = 2
    
    
    while attempts > 0:
        
# if music = music this stage will have two more prompts and if they are correct they will continue next stage.
        if music == 'music':
            print('\nCorrect! 🎶 For this music is my language and the world es mi familia 🎶 \n')

# understanding a little bit of Coco's story to understand the next input.

            coco = input( prompt =  """ \nMamá Imelda was angry with Hector (her husband) because she thought 
he had abandoned her family for music, that's why she and the rest of the family had banned 
music from their lives. When they were in the Land of the Dead something happened and that changed! 
(I won't spoil this amazing movie to you!) 
Press 'Enter' to continue.\n """)

            partner = input(prompt = """Mamá Imelda knows now that music is not bad and now 
we can sing as much as we want! You have to sing in a duet to continue through
the journey. Which Pixar character whose name starts with your same initial would 
you choose as your karaoke partner??""").title()


# if the initials do not match or there is no input: game over
            if bool(partner) == False:
                fail()

            if partner[0] == name[0]:
                print("\nGood job! \n")
                nextstage = input(prompt = f"""Santa Cecilia and The Land of the Dead were so much fun!! 
You singing with {partner}, what an amazing duo! 🎤 Did all that singing made 
you hungry? 
Press 'Enter' to fly to France to Gusteau's restaurant. ✈︎ 🇫🇷 """)
                stage3()
                break # break loop
            
            else:
                print(" \nWrong!☹️ \n ")
                fail()
    
        
        elif music == 'sports':
                music = input(prompt = """\nIncorrect! Sports? Well… I guess it would 
be sad not watching Real Madrid play! Unfortunately is the wrong answer! Try again 😊 \n""")
                attempts -= 1

        else:
            if attempts > 1:
                attempts -= 1
                music = input(prompt = """Try again 😊 \n""")
            
            else:
                fail()
                print( "\nIncorrect! Go watch Coco! \n")
        
#defining stage 3

def stage3():    
    
    print('✈︎ 🇫🇷' * 20)

    dish = input( prompt = """\nGusteau said “Anyone can cook,” but I would prefer 
to eat Remy’s ____!\n Hint: Ego loved this dish.""").casefold()
    
# ratatouille is a hard word to write, if it contains "rata" it will be okay and you go to stage 4.

    if 'rata' in dish: 
        print('\nCorrect! Let’s fuel ourselves with food.\n')
        print('🍲' * 40)
        nextstage_4 = input( prompt = """\nNow that you completed your pit stop prepare your engines! 
Let's float like a Cadillac and sting like a beamer🏎.
Press 'Enter' to race into the adventure.\n""")
        stage4()
    

    else:
        print("""\nYou didn’t know this one😧 hop into your bed and watch Ratatouille now!\n""")
        fail()
    
    
# defining stage 4    

def stage4():
    
    print('🚏 🚔 🚗 🚙 🏎 🛻'*5)

# questions list for a random question to be asked 

    questions_lst = ['What comes before the thunder?',
'Faster than fast, quicker than quick. I am ___ McQueen!]',
'In the world of racing, what leaves everyone in awe with its speed and power, just like ___ McQueen?',
'The Thunder says Ka-chicka and the ___ says Ka-chow!']                        

    random_choice = random.choice(questions_lst)


    lightning = input( prompt = f"""
Welcome! You are now in Radiator Springs! Repeat after me: I am speed. 
{random_choice}\n""" ).title()

# the answer will always be lightning and if it's correct you go to stage 5

    if lightning == 'Lightning':
        print('Ka- Chow!⚡️⚡️')
        best_friend = input (prompt = """You remember how McQueen’s best friend was Mater? 
Who’s your best friend from the MBAN’S that you would bring into this adventure?""").title()
        print( f""" \nYou and {best_friend} would have a blast! But who would be the best at provoking 
children’s screams 👀? Do you have an idea where you are going now?\n""")
        stage5()

    else:
        print('The King wouldn’t be happy with this answer…')
        fail() # if not, game over.
        
# defining stage 5 (last stage)
    
def stage5():

    print("🟢🔵"*21)
    
    advice = input( prompt = """You are now in Monstropolis! You have to prepare 
for an upcoming challenge. Who would you ask for monster advice?


Sully
Randall 
Mike Wazaosky
""").title()
    
# defining attempts for the for loop
    
    attempts = 2
    
# if answer correct next input
    
    for character in advice:
        if advice == "Sully":
            print("\nThe best option! Kitty😎\n")
            scream = input (prompt = """Let's hear your biggest shout to scare children and check 
your score!""")
            #if scream input is true, random score which if bigger than 5 will make you win the adventure
            if bool(scream) == True:
                number = random.randint(a= 1,
                                        b= 10)
                print (f"""You scored {number} out of 10!""")
            else:
                fail()
              
            
                if advice == "Sully" and number > 5:
                    print("You did great!!")
                
                
                else:
                    fail()
            
            break   # break loop if correct 
            
        elif advice == "Randall":
            attempts -= 1
            advice = input(prompt = "Oh no! Randall is the worst! Try again.").title()
            
        else:
            if attempts > 1:
                attempts -= 1
                advice = input(prompt = "Try again😊.").title()  
            
            else:
                #if incorrect in two attempts: game over.
                fail()



# defining win function

    def win():
        print(f"""\n🎊🎊Congratulations! You won the Pixar Adventure!🎊🎊\n""")
       


    win()





        

# starting game        

welcome()
# Out:
#
# Hello! Welcome to the great Pixar Adventure✨.
#
# ['Coco', 'Toy Story', 'Cars', "Monster's Inc", 'Ratatouille', 'Finding Nemo']
